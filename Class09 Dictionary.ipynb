# %% [markdown]
# ![人工智慧 - 自由團隊](https://raw.githubusercontent.com/chenkenanalytic/img/master/af/aifreeteam.png)
#
#
# <center>
#   Welcome to the first course of《Python: from business analytics to Artificial Intelligence》by AI . FREE Team.
#
#   歡迎大家來到 AI . FREE Team 《Pyhon 從商業分析到人工智慧》的第九堂課！
#
#   (Author: Chen Ken；Date of published: 2019/7/8；AI . FREE Team Website: https://aifreeblog.herokuapp.com/)</center>

# %% [markdown]
# # Dictionaries(字典)

# %% [markdown]
# * 字典是另一種可變容器模型，且可存儲任意類型對象。
#
# * 字典的每個鍵值 key=>value 對用冒號 : 分割，每個鍵值對之間用逗號 , 分割，整個字典包括在花括號 {} 中 ,格式如下所示

# %%
# dict1 ={key1:value1,key2:value2}

# %% [markdown]
# 鍵一般是唯一的，如果重複最後的一個鍵值對會替換前面的，值不需要唯一。

# %%
dict = {'a': 1, 'b': 2, 'b': '3'}
print(dict)
# Out:
# {'a': 1, 'b': '3'}

# %% [markdown]
# 值可以取任何數據類型，但鍵必須是不可變的，如字符串，數字或元組。
#
# 一個簡單的字典實例：

# %%
dict1 = {'Alice': '2341', 'Beth': '9102', 'Cecil': '3258'}
dict2 = { 'abc': 456 }
dict3 = { 'abc': 123, 98.6: 37 }
print(dict1)
print(dict2)
print(dict3)
# Out:
# {'Alice': '2341', 'Beth': '9102', 'Cecil': '3258'}
# {'abc': 456}
# {'abc': 123, 98.6: 37}

# %% [markdown]
# ## 訪問字典裏的值

# %% [markdown]
# * 把相應的鍵放入熟悉的方括弧，如下實例:

# %%
dict = {'Name': 'Soren', 'Age': 1000, 'Class': 'apple'}
 
print("dict['Name']:",dict['Name'])
print("dict['Age']:",dict['Age'])
# Out:
# dict['Name']: Soren
# dict['Age']: 1000

# %% [markdown]
# * 如果用字典裏沒有的鍵訪問數據，會輸出錯誤如下：

# %%
print("dict['family']:",dict['family'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-bf0f07c78b2a> in <module>()
# ----> 1 print("dict['family']:",dict['family'])
#
# KeyError: 'family'

# %% [markdown]
# ## 修改字典

# %% [markdown]
# * 向字典添加新內容的方法是增加新的鍵/值對，修改或刪除已有鍵/值對如下實例:

# %%
dict = {'Name': 'Lulu','Age':17,'Class':'math'}
print(dict)

dict['Name'] = 'jax'
dict['Age'] = 30
print(dict)
# Out:
# {'Name': 'Lulu', 'Age': 17, 'Class': 'math'}
# {'Name': 'jax', 'Age': 30, 'Class': 'math'}

# %% [markdown]
# ## 刪除字典元素

# %% [markdown]
# 能刪單一的元素也能清空字典，清空只需一項操作。
#
# 顯示刪除一個字典用del命令，如下實例：

# %%
dict = {'Name': 'Lulu','Age':17,'Class':'math'}
print(dict)

del dict['Name']  
print(dict)

dict.clear() 
print(dict)
# Out:
# {'Name': 'Lulu', 'Age': 17, 'Class': 'math'}
# {'Age': 17, 'Class': 'math'}
# {}

# %% [markdown]
# #### 字典鍵的特性

# %% [markdown]
# * 字典值可以沒有限制地取任何python對象，既可以是標準的對象，也可以是用戶定義的，但鍵不行。
#
# * 兩個重要的點需要記住：
#
# * 1）不允許同一個鍵出現兩次。創建時如果同一個鍵被賦值兩次，後一個值會被記住，如下實例：

# %%
dict = {'Name':'Lulu', 'Age':17, 'Name':'I am not Lulu'}
print(dict)
print(dict['Name'])
# Out:
# {'Name': 'I am not Lulu', 'Age': 17}
# I am not Lulu

# %% [markdown]
# * 2）鍵必須不可變，所以可以用數字，字符串或元組充當，所以用陣列就不行，如下實例：

# %%
dict = {['Name']:'Lulu', 'Age':17}
print(dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2ceff8cf7625> in <module>()
# ----> 1 dict = {['Name']:'Lulu', 'Age':17}
#       2 print(dict)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# * 恭喜完成本章節

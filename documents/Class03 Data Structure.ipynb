# %% [markdown]
# ![人工智慧 - 自由團隊](https://raw.githubusercontent.com/chenkenanalytic/img/master/af/aifreeteam.png)
#
#
# <center>
#   Welcome to the first course of《Python: from business analytics to Artificial Intelligence》by AI . FREE Team.
#
#   歡迎大家來到 AI . FREE Team 《Pyhon 從商業分析到人工智慧》的第三堂課！
#
#   (Author: Chen Ken；Date of published: 2019/7/8；AI . FREE Team Website: https://aifreeblog.herokuapp.com/)</center>

# %% [markdown]
# # 可變與不可變物件

# %% [markdown]
# #### 諸如（int，float，bool，str，tuple，unicode）等內建型別的物件是不可變的。像（list，set，dict）這樣的內建型別的物件是可變的

# %% [markdown]
# * 我們如何確定我們的變數是一個可變物件還是不可變物件。為此，我們應該瞭解“**ID**”和“**TYPE**”函式的用途。

# %%
x ="Holberton" 
y ="Holberton" 
print(id(x))
print(id(y))
print("x是否=y :", x is y)
# Out:
# 139891698998064
# 139891698998064
# x是否=y : True

# %% [markdown]
# * ID就像是一個變數的地址,每個地址都只會存放一個東西,如例題中 139891698998064這組ID就放了"Holberton"

# %%
num = 2
print(type(num))
string1 = "It's a string"
print(type(string1))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# * TYPE就是每個變數的型別,不同的型別,存放的資料也不同,例如:int存放整數、float存放浮點數、list存放陣列等等的...

# %% [markdown]
# #### 現在我們已經看到了如何比較兩個簡單的字串變數來找出型別和ID。因此，使用這兩個函式，我們可以檢查不同型別的物件是如何與變數相關聯以及如何更改物件的。
#
# * 可變物件 list,dict,set
# * 不可變物件 int,string,float,tuple

# %%
x = 10
y = "test"
print(id(x),x)
print(id(y),y)
x = y
print(id(x),x)
print(id(y),y)
# Out:
# 10969088 10
# 139892257508856 test
# 139892257508856 test
# 139892257508856 test
# True

# %% [markdown]
# * 在這個程式我們可以發現,在python的世界 = 不只是賦值,而且還把地址也一併更改了

# %%
id(x)!=id(y)
# Out:
# False

# %%
id(x)!=id(10)
# Out:
# True

# %% [markdown]
# * x被標記的物件被改變。**物件10從未被修改過**。不可變物件在建立後**不允許修改**

# %% [markdown]
# #### 我們再來看看可變物件的例子

# %%
m = list([1,2,3])
print(m)
n = m
print(n,m)
id(m)==id(n)
# Out:
# [1, 2, 3]
# [1, 2, 3] [1, 2, 3]
# True

# %% [markdown]
# * 接下來我們使用python內建的功能pop(),pop()功能是把陣列的最後一個物件丟出來,詳細用法之後章節會介紹

# %%
m.pop()
print(m)
print(n)
# Out:
# [1, 2]
# [1, 2]

# %% [markdown]
# * 我們可以看到m,n之間是有連動性的,我們使用id來檢查

# %%
print(id(m))
print(id(n))
id(m)== id(n)
# Out:
# True

# %% [markdown]
# * 上述的例子,m和n將在修改後指向同一個列表物件。列表物件現在將包含[1，2]。

# %% [markdown]
# * Python以不同方式處理可變物件和不可變物件。
# * *不可變的訪問比可變物件更快。*
# * 當你需要改變物件的大小，例如列表，字典等等時，可變物件是很好用的。當你需要確保* 你建立的物件始終保持不變時，**使用不可變物件**。
# * 不可變物件對於**“更改”**而言基本上是緩慢的，因為這樣做涉及到建立副本。更改可變物件很快速。
#
# ##### 不可變的例外..
